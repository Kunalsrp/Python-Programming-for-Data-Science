# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\EXCELR DS Material\PYTHON\DATASET\Salaries.csv")

# %%
import matplotlib.pyplot as plt

# %%
df.index
# Out:
# RangeIndex(start=0, stop=78, step=1)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#BAR PLOT
#value_counts()  gives the no of unique values
df["discipline"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#SCATTER PLOT
ages = [ 25,35,40,30,48,50]
salary = [22000, 30000,23000,35000, 27000, 40000]
plt.xlabel("Ages of people")
plt.ylabel("Salary of people")
plt.title("Salary distribution of employees")
plt.scatter(ages,salary,color="red")

# %%
x = [-5,-2,-1,2,4,6,7,10]
y = [35,34,60,50,20,70,90,80]
plt.figure(figsize=(6,4))       #dimensions of figure in inches
plt.suptitle("Learning Visualisation",size=25)
plt.xlim(-20,20)
plt.ylim(10,100)
plt.plot(x,y)

# %%
#plot graph of nos. from (-100 to 100) and its square . using range function
x = list(range(-100,100))
y = [i**2 for i in x]   #list comprehension
plt.plot(x,y)

# %%
from math import exp 
x = list(range(0,30))
y = [exp(i) for i in x]   #list comprehension
plt.plot(x,y)

# %%
from math import log 
x = list(range(1,101))
y = [log(i) for i in x]   #list comprehension
plt.plot(x,y)

# %%
#plot multiple at a time : eg 12 graph at a time = 3x4
from math import *
plt.figure(figsize=(16,9)) 
x = list(range(-10,11))
y = [i**2 for i in x]
plt.subplot(3,4,1)        # 3 row 4 column and 1st position of grid
plt.plot(x,y)

y = [i**3 for i in x]
plt.subplot(3,4,8)        #  8th position of grid
plt.plot(x,y)

y = [sin(i) for i in x] 
plt.subplot(3,4,10)        #  10th position of grid
plt.plot(x,y)

# %%
data = pd.read_csv(r"E:\EXCELR DS Material\PYTHON\DATASET\mtcars.csv")

# %%
data
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14  10.4    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# 15  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3     4
# 16  14.7    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 17  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4     1
# 18  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 19  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4     1
# 20  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3     1
# 21  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3     2
# 22  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3     2
# 23  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3     4
# 24  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3     2
# 25  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4     1
# 26  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 27  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5     2
# 28  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5     4
# 29  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5     6
# 30  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5     8
# 31  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4     2

# %%
data.shape
# Out:
# (32, 11)

# %%
data.shape[0]
# Out:
# 32

# %%
#crosstable is used to find the certain unique no of cylinder and the gears in matrix format
pd.crosstab(data['cyl'],data['gear']) #rows,columns
# Out:
# gear   3  4  5
# cyl
# 4      1  8  2
# 6      2  4  1
# 8     12  0  2

# %%
pd.crosstab(data['gear'],data['cyl']) #rows,columns
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
pd.crosstab(data['cyl'],data['gear']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='cyl'>

# %%
data['gear'].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
data['gear'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='gear'>

# %%
plt.scatter(data.mpg,data.qsec,color="green")

# %%
#HISTOGRAM
plt.hist(data.mpg,edgecolor="red")
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
#bins is used to customize the no of bars
plt.hist(data.mpg,facecolor="yellow",edgecolor="red",bins=6)
# Out:
# (array([ 4., 10.,  9.,  4.,  1.,  4.]),
#  array([10.4       , 14.31666667, 18.23333333, 22.15      , 26.06666667,
#         29.98333333, 33.9       ]),
#  <BarContainer object of 6 artists>)

# %%
plt.boxplot(data.mpg)
plt.show()

# %%
plt.boxplot(data.mpg,vert=False,notch=True)     #notch id line between the plot
plt.show()

# %%
import numpy as np
mtcars = pd.read_csv(r"E:\EXCELR DS Material\PYTHON\DATASET\mtcars.csv")

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
mtcars.shape
# Out:
# (32, 11)

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
mtcars.tail()
# Out:
#      mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  carb
# 27  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5     2
# 28  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5     4
# 29  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5     6
# 30  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5     8
# 31  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4     2

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %%
mtcars.hist(figsize=(15,5))
plt.show()

# %%
plt.figure(facecolor='yellow')
plt.scatter(mtcars.mpg,mtcars.qsec,marker='+')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.violinplot(mtcars["mpg"])
plt.show()

# %%
plt.violinplot(mtcars["mpg"])
box=plt.boxplot(mtcars["mpg"])
plt.show()

# %% [markdown]
# # SEABORN

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')  #tips is inbuilt dataset in seaborn

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
pd.crosstab(tips['smoker'],tips["sex"])
# Out:
# sex     Male  Female
# smoker
# Yes       60      33
# No        97      54

# %%
pd.crosstab(tips['smoker'],tips["sex"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='smoker'>

# %%
sns.stripplot(y='tip',data=tips)  #tip is column and tips is dataset
plt.show()

# %%
sns.stripplot(x="sex", y='tip',data=tips,jitter=True)  #sex,tip is column name and tips is dataset
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x="day", y='tip',data=tips,jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day", y='tip',data=tips,size=4,jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x="day", y='tip',data=tips,size=4)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x="day", y='tip',data=tips,hue='sex')    #hue rep the third parameter/column
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x="day", y='tip',data=tips,hue='time')
plt.show()

# %%
#SUBPLOTS
plt.subplot(2,2,1) # nrows,ncols,position
sns.boxplot(x='day', y='tip', data=tips)

plt.subplot(2,2,2) # nrows,ncols,position
sns.boxplot(x='day', y='tip', data=tips)
#plt.ylabel=('tip ($)')
#plt.title=("Boxplot of tips")

plt.subplot(2,2,3)
sns.violinplot(x='day', y='tip', data=tips)

plt.subplot(2,2,4)
sns.violinplot(x='day', y='tip', data=tips)
#plt.ylabel=('tip ($)')
#plt.title=("violin plot of tips")
plt.show()

# %%
##Combining plots
# check sns.violinplot documentation

sns.violinplot(x='day', y='tip', data=tips, inner="stick", color='yellow')
sns.stripplot(x='day', y='tip', data=tips, size=4,jitter=True)
#plt.ylabel=('tip ($)')
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Observation: tip amount is increasing with total bill value
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='time')
# same points plotted but as per time - lunch & dinner
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#Swarm plot
plt.figure(figsize=(10,5))
sns.swarmplot(x='day', y='tip', data=tips)
sns.violinplot(x='day',y='tip',data=tips,color='black')
#plt.ylabel('tip ($)')
plt.show()

# %%
#Changing orientation
sns.swarmplot(x='tip', y='day', data=tips, hue='sex',orient='h')
#plt.xlabel=('tip ($)')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Box and Violin plot

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x='day', y='tip',data=tips)
sns.boxplot(x='day', y='tip', data=tips)

#plt.ylabel('tip ($)')
plt.show()

# %%
sns.violinplot(x='day', y='tip', data=tips)
#plt.ylabel('tip ($)')

plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig,ax=plt.subplots(nrows=2,ncols=2) # empty spaces for plots, change nrows and ncols

# %%
sns.histplot(x= 'total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x= 'tip',data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
#Joint plot - scatter plot and individual histogram of x and y variables

sns.jointplot(x= 'total_bill', y= 'tip', data=tips)
plt.show()

# %%
pd.plotting.scatter_matrix(tips)
plt.show()

# %%
#Pair plot : If dataset has many numeric columns, you can plot many plots of diff. combination using pairplot
# diagonally it gives histo or bar plot of individual plot of total_bill, tip and size
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips, hue='sex') # diagonally male female distribution
plt.show() # try hue=time,smoker,day,etc. to check diff. patterns, gain more information

# %% [markdown]
# # Titanic data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading dataset

# %%
data = pd.read_csv(r'E:\EXCELR DS Material\PYTHON\DATASET\train.csv') # provide train.csv through chat window
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Data types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.shape
# Out:
# (891, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Proportion of target (Survived)

# %%
data.groupby('Survived')['PassengerId'].count()
# 549 passangers could not survive, 342 - survived
# try groupby - Sex,groupby(['Survived','Sex'])
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
pd.crosstab(data['Survived'],data['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# ### Visual Exploration

# %%
pd.crosstab(data['Survived'],data['Sex']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Survived', y="Age",  data=data);

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='Sex', y="Survived",  data=data);

# %%
plt.figure(figsize=(11,5))
sns.boxplot(x="Sex", y="Age", hue="Survived", data=data);

# %%
sns.barplot(x="Pclass", y="Survived", data=data);

# %%
sns.barplot(x="Pclass", y="Survived",hue="Sex", data=data);

# %%
sns.barplot(x="SibSp", y="Survived", data=data);

# %%
sns.barplot(x="Parch", y="Survived", data=data);

# %%
data.loc[data['Survived']==1,"Age"] # age col contains some na values
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# 889    26.0
# Name: Age, Length: 342, dtype: float64

# %%
survived = data.loc[data['Survived']==1,"Age"].dropna()
sns.distplot(survived)
# plt.title=("Survived");
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
not_survived = data.loc[data['Survived']==0,"Age"].dropna()
sns.distplot(not_survived)
# plt.title=("Not Survived");
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.pairplot(data); #scatterplot of all variables

# %%
# Pclass vs Survive
grid = sns.FacetGrid(data, col='Survived', row='Pclass', height=2.4, aspect=1.5)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend()

# %%
figbi, axesbi = plt.subplots(2, 4, figsize=(18, 10))
data.groupby('Pclass')['Survived'].mean().plot(kind='barh',ax=axesbi[0,0],xlim=[0,1])
data.groupby('SibSp')['Survived'].mean().plot(kind='barh',ax=axesbi[0,1],xlim=[0,1])
data.groupby('Parch')['Survived'].mean().plot(kind='barh',ax=axesbi[0,2],xlim=[0,1])
data.groupby('Sex')['Survived'].mean().plot(kind='barh',ax=axesbi[0,3],xlim=[0,1])
data.groupby('Embarked')['Survived'].mean().plot(kind='barh',ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x="Survived", y="Age", data=data,ax=axesbi[1,1])
sns.boxplot(x="Survived", y="Fare", data=data,ax=axesbi[1,2])
plt.show()
figbi.savefig("my1stfig.png")
from google.colab import files
files.download("my1stfig.png")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15940\4113122341.py in <module>
#       9 plt.show()
#      10 figbi.savefig("my1stfig.png")
# ---> 11 from bokeh.plotting import files
#      12 files.download("my1stfig.png")
#
# ImportError: cannot import name 'files' from 'bokeh.plotting' (C:\Users\Admin\anaconda3\lib\site-packages\bokeh\plotting\__init__.py)
